# %% [markdown]
# **Project 5.2 Part 9: Large Language Model and Text Generation**
# Jacqueline Brown

# %%
#install the transformers library
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from transformers import pipeline, set_seed
# Here, 'text-generation' tells the pipeline to create a text generation model, and model='gpt2'
# specifies that you want to use the GPT-2 model for this task.
generator = pipeline('text-generation', model='gpt2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
set_seed(100)
input_text = "This project used natural language processing and large language models"
# specifying the maximum length of the output, and the number of different sequences you want
output = generator(input_text, max_length=50, num_return_sequences=5)
for result in output:
    print(result['generated_text'])
    print("----")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# This project used natural language processing and large language models to construct our first-generation version of a model for humans (D. K. & M. Miao) where we used natural language to understand the concept of human cognition and that of their emotions
# ----
# This project used natural language processing and large language models to create and produce a text file that contains all the information that people can interact with from websites like Google, LinkedIn, and other social sites. A large number of users use it for such an experience
# ----
# This project used natural language processing and large language models (MLR) to show how many different languages within each language, but the results were highly interesting and intriguing. We were lucky enough to get a free, full-sized version of the software (
# ----
# This project used natural language processing and large language models. It uses simple language constructs, but they are extremely high performance models. These models can be very interesting for other tasks or tasks that might not have the natural language processing.
#
# The result is
# ----
# This project used natural language processing and large language models to explore the properties of languages in a more natural way. Each model included an explicit language mapping that is based on the semantics of an explicit language.
#
# In my view, a native language is
# ----

# %%
# testing hyperparameters
set_seed(100)
input_text = "This project used natural language processing and large language models"
# specifying the maximum length of the output, and the number of different sequences you want
output = generator(input_text, max_length=50, num_return_sequences=5, temperature = .5)
for result in output:
    print(result['generated_text'])
    print("----")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# This project used natural language processing and large language models to construct a simple, but powerful, programming language for AI.
#
# Our goal is to create a language that makes it easy to build, execute, and manage AI.
#
# A simple,
# ----
# This project used natural language processing and large language models to create a complex, multilingual, and simple-to-use program. The program was written in C, which is the language of choice for most programming languages.
#
# This project used natural
# ----
# This project used natural language processing and large language models to create a large language model. The model was then used to predict the distribution of language words. The model was then used to predict the distribution of word distribution in a subset of the language words.
# ----
# This project used natural language processing and large language models to create a simple, easy-to-use, and flexible language model for programming language processing. The language model uses the following APIs to create user-defined language models:
#
# The API for
# ----
# This project used natural language processing and large language models to explore the relationship between language and cognition. It was shown that language and cognition are related to the ability to use and recall information about information, and that language is associated with a greater number of information
# ----

# %%
# increasing temp, the results were not as wild as I imagined

set_seed(100)
input_text = "This project used natural language processing and large language models"
# specifying the maximum length of the output, and the number of different sequences you want
output = generator(input_text, max_length=50, num_return_sequences=5, temperature = 1.7)
for result in output:
    print(result['generated_text'])
    print("----")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# This project used natural language processing and large language models to construct our first-generation version of a model and, with an input type type such a dictionary format string object. The second version uses realtime analysis of various type names in a language called machine
# ----
# This project used natural language processing and large language models—as well as machine learning analysis and visual models that were modeled based a priori upon human comprehension models—as well to test hypotheses to further augment natural world inference in cognitive science for human language processing
# ----
# This project used natural language processing and large language models which provides full integration. Our students learn the traditional ways that animals, but also many social, behavioral sciences in real-time in such a programmable structure. Using a computational system (crawler
# ----
# This project used natural language processing and large language models. It uses simple hierarchical databases containing thousands on-going users or groups of users by language (as in many other research sites), which includes a user (for example, German, French and Italian).
# ----
# This project used natural language processing and large language models to explore the properties of information representations to classify the brain. Each model included an explicit training block that is based of neural models (neural networks of the lateral gyrus), a structured input task which
# ----
